# %%
import pandas as pd
import psycopg2
import sqlalchemy

# %%
url = 'postgresql+psycopg2://lemleyj:password@localhost:5432/cs361'
engine = sqlalchemy.create_engine(url)

# %%
# sql = "select pitcher_stats.Name FROM pitcher_stats"
sql = "SELECT * FROM pitcher_stats"
df = pd.read_sql(sql,con=engine)
df
# Out:
#       Season                Name   Team   W   L  SV   G  GS     IP    K/9  \
# 0       2018        Jacob deGrom    NYM  10   9   0  32  32  217.0  11.16
# 1       2011        Roy Halladay    PHI  19   6   0  32  32  233.2   8.47
# 2       2015     Clayton Kershaw    LAD  16   7   0  33  33  232.2  11.64
# 3       2014     Clayton Kershaw    LAD  21   3   0  27  27  198.1  10.85
# 4       2017          Chris Sale    BOS  17   8   0  32  32  214.1  12.93
# ...      ...                 ...    ...  ..  ..  ..  ..  ..    ...    ...
# 9702    2018       Jarlin Garcia    MIA   3   3   0  29   7   66.0   5.45
# 9703    2018         Josh Tomlin    CLE   2   5   0  32   9   70.1   5.89
# 9704    2010  Ryan Rowland-Smith    SEA   1  10   0  27  20  109.1   4.03
# 9705    2011      Bronson Arroyo    CIN   9  12   0  32  32  199.0   4.88
# 9706    2011       Scott Proctor  - - -   2   6   0  39   0   40.1   6.47
#
#       ...  HR/9  BABIP     LOB      GB   HR_FB   ERA  xERA   FIP  xFIP  WAR
# ...

# %%
from sqlalchemy import create_engine, select, MetaData, Table, and_

engine = create_engine("postgresql+psycopg2://lemleyj:password@localhost:5432/cs361")
metadata = MetaData(bind=None)
table = Table(
    'pitcher_stats', 
    metadata, 
    autoload=True, 
    autoload_with=engine
)

# stmt = select([
#     table.columns.Name,
#     table.columns.Team,
#     table.columns['K/9']
# ]).where(and_(
#     table.columns.Name == 'Justin Verlander',
# #     table.columns.column2 == 'filter2'
# ))

list_of_cols = ['Name','Season','Team','K/9','HR/9']

query_dict = {'Name':'Justin Verlander',
#              'Season':int("2018"),
             }


stmt = select(
    [table.columns[col] for col in list_of_cols]
            ).where(and_(
                x for x in [table.columns[k] == v for k, v in query_dict.items()]))

connection = engine.connect()
results = connection.execute(stmt).fetchall()

# %%
for result in results: 
    print(result)
# Out:
# ('Justin Verlander', 2012, 'DET', 9.03, 0.72)
# ('Justin Verlander', 2010, 'DET', 8.79, 0.56)
# ('Justin Verlander', 2018, 'HOU', 12.2, 1.18)
# ('Justin Verlander', 2011, 'DET', 8.96, 0.86)
# ('Justin Verlander', 2019, 'HOU', 12.11, 1.45)
# ('Justin Verlander', 2022, 'HOU', 9.51, 0.62)
# ('Justin Verlander', 2016, 'DET', 10.04, 1.19)
# ('Justin Verlander', 2013, 'DET', 8.95, 0.78)
# ('Justin Verlander', 2017, '- - -', 9.57, 1.18)
# ('Justin Verlander', 2014, 'DET', 6.95, 0.79)
# ('Justin Verlander', 2015, 'DET', 7.63, 0.88)
# ('Justin Verlander', 2020, 'HOU', 10.5, 3.0)

# %%
pd.DataFrame(results, columns=list_of_stuff).sort_values('Season')
# Out:
#                 Name  Season   Team    K/9  HR/9
# 1   Justin Verlander    2010    DET   8.79  0.56
# 3   Justin Verlander    2011    DET   8.96  0.86
# 0   Justin Verlander    2012    DET   9.03  0.72
# 7   Justin Verlander    2013    DET   8.95  0.78
# 9   Justin Verlander    2014    DET   6.95  0.79
# 10  Justin Verlander    2015    DET   7.63  0.88
# 6   Justin Verlander    2016    DET  10.04  1.19
# 8   Justin Verlander    2017  - - -   9.57  1.18
# 2   Justin Verlander    2018    HOU  12.20  1.18
# 4   Justin Verlander    2019    HOU  12.11  1.45
# 11  Justin Verlander    2020    HOU  10.50  3.00
# 5   Justin Verlander    2022    HOU   9.51  0.62
