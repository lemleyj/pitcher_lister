# %%
import pandas as pd

# %%
df = pd.read_csv('../pitcher_stats.csv').sort_values('Season')
# df = df.set_index('Name')
# df = df.set_index('playerid')

# %%
df
# Out:
#       Season              Name   Team   W   L  SV   G  GS     IP    K/9  ...  \
# 0       2010       Jamie Moyer    PHI   9   9   0  19  19  111.2   5.08  ...
# 415     2010       Kevin Gregg    TOR   2   6  37  63   0   59.0   8.85  ...
# 416     2010       Jesse Crain    MIN   1   1   1  71   0   68.0   8.21  ...
# 417     2010       Josh Tomlin    CLE   6   4   0  12  12   73.0   5.30  ...
# 418     2010        Roy Oswalt  - - -  13  13   0  33  32  211.2   8.21  ...
# ...      ...               ...    ...  ..  ..  ..  ..  ..    ...    ...  ...
# 9009    2022    Jerad Eickhoff    PIT   0   1   0   1   1    4.1   8.31  ...
# 9010    2022  Justus Sheffield    SEA   1   0   0   6   1   11.2   5.40  ...
# 9011    2022      Hunter Brown    HOU   2   0   0   7   2   20.1   9.74  ...
# 9013    2022        Ian Gibaut  - - -   1   2   1  34   0   36.0  12.00  ...
# 9577    2022     Luis Gonzalez    SFG   0   0   0   5   0    6.1   0.00  ...
#
#       BABIP     LOB      GB   HR_FB    ERA xERA    FIP  xFIP  WAR  playerid
# 0     0.236  64.40%  44.10%  13.20%   4.84  NaN   4.98  4.30  0.2      1091
# 415   0.298  76.20%  42.30%   6.10%   3.51  NaN   3.57  4.05  0.7      1793
# 416   0.262  73.00%  39.20%   6.30%   3.04  NaN   3.45  3.93  0.7      4817
# 417   0.274  70.00%  28.40%   8.50%   4.56  NaN   4.58  4.76  0.7      9388
# 418   0.253  77.80%  45.70%   9.10%   2.76  NaN   3.27  3.30  4.4       571
# ...     ...     ...     ...     ...    ...  ...    ...   ...  ...       ...
# 9009  0.471  35.70%  42.10%  28.60%  20.77  NaN  10.04  6.43 -0.2     12664
# 9010  0.222  75.30%  58.30%  11.10%   3.86  NaN   4.83  4.86 -0.1     17285
# 9011  0.294  90.90%  68.00%   0.00%   0.89  NaN   1.98  2.78  0.6     25880
# 9013  0.400  74.30%  37.60%   8.30%   4.50  NaN   3.11  3.51  0.6     17871
# 9577  0.310  60.00%  53.60%   0.00%   5.68  NaN   3.59  5.22  0.0     20332
#
# [9578 rows x 22 columns]

# %%
pitcher_name = 'Carlos Rodon'
pitcher_id = 16137
temp_df = df[df['playerid'] == pitcher_id].sort_values('Season').reset_index()
table_records = temp_df.to_dict('records')

# %%
table_records
# Out:
# [{'index': 3323,
#   'Season': 2015,
#   'Name': 'Carlos Rodon',
#   'Team': 'CHW',
#   'W': 9,
#   'L': 6,
#   'SV': 0,
#   'G': 26,
#   'GS': 23,
#   'IP': 139.1,
#   'K/9': 8.98,
#   'BB/9': 4.59,
#   'HR/9': 0.71,
#   'BABIP': 0.315,
#   'LOB': '75.40%',
#   'GB': '46.80%',
#   'HR_FB': '9.80%',
#   'ERA': 3.75,
#   'xERA': nan,
#   'FIP': 3.87,
#   'xFIP': 4.03,
#   'WAR': 1.7,
#   'playerid': 16137},
#  {'index': 4211,
#   'Season': 2016,
#   'Name': 'Carlos Rodon',
#   'Team': 'CHW',
#   'W': 9,
#   'L': 10,
#   'SV': 0,
#   'G': 28,
#   'GS': 28,
#   'IP': 165.0,
#   'K/9': 9.16,
#   'BB/9': 2.95,
#   'HR/9': 1.25,
#   'BABIP': 0.33,
#   'LOB': '75.60%',
#   'GB': '44.10%',
#   'HR_FB': '13.80%',
#   'ERA': 4.04,
#   'xERA': nan,
#   'FIP': 4.01,
#   'xFIP': 3.89,
#   'WAR': 2.7,
#   'playerid': 16137},
#  {'index': 4940,
#   'Season': 2017,
#   'Name': 'Carlos Rodon',
#   'Team': 'CHW',
#   'W': 2,
#   'L': 5,
#   'SV': 0,
#   'G': 12,
#   'GS': 12,
#   'IP': 69.1,
#   'K/9': 9.87,
#   'BB/9': 4.02,
#   'HR/9': 1.56,
#   'BABIP': 0.297,
#   'LOB': '77.60%',
#   'GB': '44.10%',
#   'HR_FB': '19.00%',
#   'ERA': 4.15,
#   'xERA': nan,
#   'FIP': 4.69,
#   'xFIP': 4.05,
#   'WAR': 0.6,
#   'playerid': 16137},
#  {'index': 6175,
#   'Season': 2018,
#   'Name': 'Carlos Rodon',
#   'Team': 'CHW',
#   'W': 6,
#   'L': 8,
#   'SV': 0,
#   'G': 20,
#   'GS': 20,
#   'IP': 120.2,
#   'K/9': 6.71,
#   'BB/9': 4.1,
#   'HR/9': 1.12,
#   'BABIP': 0.242,
#   'LOB': '72.00%',
#   'GB': '41.50%',
#   'HR_FB': '9.90%',
#   'ERA': 4.18,
#   'xERA': nan,
#   'FIP': 4.95,
#   'xFIP': 5.4,
#   'WAR': 0.9,
#   'playerid': 16137},
#  {'index': 6325,
#   'Season': 2019,
#   'Name': 'Carlos Rodon',
#   'Team': 'CHW',
#   'W': 3,
#   'L': 2,
#   'SV': 0,
#   'G': 7,
#   'GS': 7,
#   'IP': 34.2,
#   'K/9': 11.94,
#   'BB/9': 4.41,
#   'HR/9': 1.04,
#   'BABIP': 0.322,
#   'LOB': '63.90%',
#   'GB': '43.00%',
#   'HR_FB': '11.40%',
#   'ERA': 5.19,
#   'xERA': nan,
#   'FIP': 3.62,
#   'xFIP': 4.13,
#   'WAR': 0.9,
#   'playerid': 16137},
#  {'index': 7705,
#   'Season': 2020,
#   'Name': 'Carlos Rodon',
#   'Team': 'CHW',
#   'W': 0,
#   'L': 2,
#   'SV': 0,
#   'G': 4,
#   'GS': 2,
#   'IP': 7.2,
#   'K/9': 7.04,
#   'BB/9': 3.52,
#   'HR/9': 1.17,
#   'BABIP': 0.333,
#   'LOB': '51.70%',
#   'GB': '28.00%',
#   'HR_FB': '8.30%',
#   'ERA': 8.22,
#   'xERA': nan,
#   'FIP': 4.89,
#   'xFIP': 6.21,
#   'WAR': 0.1,
#   'playerid': 16137},
#  {'index': 7993,
#   'Season': 2021,
#   'Name': 'Carlos Rodon',
#   'Team': 'CHW',
#   'W': 13,
#   'L': 5,
#   'SV': 0,
#   'G': 24,
#   'GS': 24,
#   'IP': 132.2,
#   'K/9': 12.55,
#   'BB/9': 2.44,
#   'HR/9': 0.88,
#   'BABIP': 0.267,
#   'LOB': '82.20%',
#   'GB': '37.70%',
#   'HR_FB': '9.60%',
#   'ERA': 2.37,
#   'xERA': nan,
#   'FIP': 2.65,
#   'xFIP': 3.17,
#   'WAR': 4.9,
#   'playerid': 16137},
#  {'index': 8929,
#   'Season': 2022,
#   'Name': 'Carlos Rodon',
#   'Team': 'SFG',
#   'W': 14,
#   'L': 8,
#   'SV': 0,
#   'G': 31,
#   'GS': 31,
#   'IP': 178.0,
#   'K/9': 11.98,
#   'BB/9': 2.63,
#   'HR/9': 0.61,
#   'BABIP': 0.293,
#   'LOB': '75.10%',
#   'GB': '34.10%',
#   'HR_FB': '6.50%',
#   'ERA': 2.88,
#   'xERA': nan,
#   'FIP': 2.25,
#   'xFIP': 2.91,
#   'WAR': 6.2,
#   'playerid': 16137}]

# %%
table_dict[0]
# Out:
# {'index': 3323,
#  'Season': 2015,
#  'Name': 'Carlos Rodon',
#  'Team': 'CHW',
#  'W': 9,
#  'L': 6,
#  'SV': 0,
#  'G': 26,
#  'GS': 23,
#  'IP': 139.1,
#  'K/9': 8.98,
#  'BB/9': 4.59,
#  'HR/9': 0.71,
#  'BABIP': 0.315,
#  'LOB': '75.40%',
#  'GB': '46.80%',
#  'HR_FB': '9.80%',
#  'ERA': 3.75,
#  'xERA': nan,
#  'FIP': 3.87,
#  'xFIP': 4.03,
#  'WAR': 1.7,
#  'playerid': 16137}

# %%
len(temp_df)
# Out:
# 8
