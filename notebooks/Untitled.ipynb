# %%
import pandas as pd

# %%
df = pd.read_csv('../pitcher_stats.csv').sort_values('Season')
df = df.set_index('Name')

# %%
df
# Out:
#                Season   Team  W  L  SV   G  GS     IP    K/9  BB/9  HR/9  \
# Name
# Jamie Moyer      2010    PHI  9  9   0  19  19  111.2   5.08  1.61  1.61
# Daniel Bard      2010    BOS  1  2   3  73   0   74.2   9.16  3.62  0.72
# Koji Uehara      2010    BAL  1  2  13  43   0   44.0  11.25  1.02  1.02
# Carlos Fisher    2010    CIN  1  1   0  18   0   22.1   8.46  5.24  0.40
# Chris Ray        2010  - - -  5  0   2  63   0   55.2   5.01  4.04  0.81
# ...               ...    ... .. ..  ..  ..  ..    ...    ...   ...   ...
# Art Warren       2022    CIN  2  3   3  39   0   36.0  10.00  5.50  1.50
# Greg Weissert    2022    NYY  3  0   0  12   0   11.1   8.74  3.97  0.79
# Michael Grove    2022    LAD  1  0   0   7   6   29.1   7.36  3.07  1.84
# Ryan Tepera      2022    LAA  5  4   6  59   0   57.1   7.38  3.14  1.10
# Luis Gonzalez    2022    SFG  0  0   0   5   0    6.1   0.00  1.42  0.00
#
#                BABIP     LOB      GB   HR_FB   ERA  xERA   FIP  xFIP  WAR
# Name
# ...

# %%
df.loc['Justin Verlander']
# Out:
#                   Season   Team   W   L  SV   G  GS     IP    K/9  BB/9  HR/9  \
# Name
# Justin Verlander    2010    DET  18   9   0  33  33  224.1   8.79  2.85  0.56
# Justin Verlander    2011    DET  24   5   0  34  34  251.0   8.96  2.04  0.86
# Justin Verlander    2012    DET  17   8   0  33  33  238.1   9.03  2.27  0.72
# Justin Verlander    2013    DET  13  12   0  34  34  218.1   8.95  3.09  0.78
# Justin Verlander    2014    DET  15  12   0  32  32  206.0   6.95  2.84  0.79
# Justin Verlander    2015    DET   5   8   0  20  20  133.1   7.63  2.16  0.88
# Justin Verlander    2016    DET  16   9   0  34  34  227.2  10.04  2.25  1.19
# Justin Verlander    2017  - - -  15   8   0  33  33  206.0   9.57  3.15  1.18
# Justin Verlander    2018    HOU  16   9   0  34  34  214.0  12.20  1.56  1.18
# Justin Verlander    2019    HOU  21   6   0  34  34  223.0  12.11  1.70  1.45
# Justin Verlander    2020    HOU   1   0   0   1   1    6.0  10.50  1.50  3.00
# ...

# %%
df.columns.tolist()
# Out:
# ['Season',
#  'Team',
#  'W',
#  'L',
#  'SV',
#  'G',
#  'GS',
#  'IP',
#  'K/9',
#  'BB/9',
#  'HR/9',
#  'BABIP',
#  'LOB',
#  'GB',
#  'HR_FB',
#  'ERA',
#  'xERA',
#  'FIP',
#  'xFIP',
#  'WAR']
